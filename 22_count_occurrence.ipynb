# %%
class CountOccurrence:
    def __init__(self  , user_str):
        if not isinstance(user_str , str):
            raise TypeError("input must be str")

        if user_input.strip() == "":
            raise ValueError("input can not be empty")
        self.str = user_str

    def count_occurrence(self):
        count = {}

        for i in self.str:
            count[i] = count.get(i , 0) + 1

        return count
if __name__ == "__main__":
    try:
        user_input= input("enter your word : ")
        obj = CountOccurrence(user_input)
        print(obj.count_occurrence())

    except Exception as e:
        print(e)
# Out:
# enter your word :  upasana sharma
# {'u': 1, 'p': 1, 'a': 5, 's': 2, 'n': 1, ' ': 1, 'h': 1, 'r': 1, 'm': 1}
