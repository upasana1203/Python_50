# %%
class FindLongest:
    def __init__(self, sentence):
        if isinstance(sentence, bool):
            raise TypeError("Boolean values are not allowed")

        if not isinstance(sentence, str):
            raise TypeError("Input must be a string")

        if not sentence.strip():
            raise ValueError("Sentence must not be empty")

        self.sent = sentence

    def find_longest(self):
        words = self.sent.split()

        if not words:
            raise ValueError("No words found in the sentence")

        max_len = 0
        for word in words:
            if len(word) > max_len:
                max_len = len(word)

        return max_len


if __name__ == "__main__":
    try:
        obj = FindLongest("i got supercalifragilistic score in last test")
        print("the longest word is of length : ", obj.find_longest())
    except Exception as e:
        print(e)
# Out:
# the longest word is of length :  20

# %%
# other possible solutions
def find_longest(sent):
    return max(map(len, sent.split()))

# %%
def find_longest(sent):
    longest_word = max(sent.split(), key=len)
    return longest_word, len(longest_word)

# %%
def find_longest(sent):
    return max([len(word) for word in sent.split()])

# %%
def find_longest(sent):
    longest_word = max(sent.split(), key=len)
    return longest_word, len(longest_word)
