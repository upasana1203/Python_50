# %%
class TupleToDict:
    def __init__(self,tup1):

        if not isinstance(tup1 , list):
            raise TypeError("input type must be list")

        if not tup1:
            raise ValueError("Input must not be empty")

        for item in self.tup:
            if not isinstance(item, tuple):
                raise TypeError("Each element must be a tuple")

            if len(item) != 2:
                raise ValueError("Each tuple must contain exactly 2 elements")
        self.tup = tup1

    def tuple_to_dict(self):
        dict1 = {}
        for key , value in self.tup:
            dict1[key] = value
        retur
            

if __name__ == "__main__":
    try:
        obj = TupleToDict([('a', 1), ('b', 2), ('c', 3), ('d', 4)])
        print(obj.tuple_to_dict())

    except Exception as e:
        print(e)
# Out:
# name 'data' is not defined
