# %%
class ReverseSentence:
    def __init__(self , user_str):
        if not isinstance(user_str, str):
            raise TypeError("Input must be a string")
    
        if user_str.strip() == "":
            raise ValueError("Sentence cannot be empty")
        self.user_str = user_str
        
    def reverse_words(self):  
        words = self.user_str.split()
        reversed_sentence = ""
    
        for i in range(len(words) - 1, -1, -1):
            reversed_sentence = reversed_sentence + words[i]
            if i != 0:
                reversed_sentence += " "
    
        return reversed_sentence

if __name__ == "__main__":
    try:
        user_input = input("enter your sentence : ")
        obj = ReverseSentence(user_input)
        print(obj.reverse_words())
    except Exception as e:
        print(e)
# Out:
# enter your sentence :  bh hju jkj jkj jkjkl
# jkjkl jkj jkj hju bh
