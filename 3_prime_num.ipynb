# %%
class Prime:
    """
    function:
        checks if number is prime or not

    args:
        num: integer number to check

    return:
        True if prime, False if not

    raises:
        TypeError : if num is not int
    """
    def __init__(self , num):
        self.num = num

    def is_prime(self):
        
            
        if self.num <= 1:
            return False
            
        for i in range(2 , self.num):
            if self.num % i == 0:
                return False
                
        return True
        
if __name__ == "__main__":
        try:
            user_input = int(input("Enter a number: "))
            prime_obj = Prime(user_input)
            result = prime_obj.is_prime()

        
            if result:
                print("Prime number")
            else:
                print("Not a prime number")
    
        except ValueError:
            print("Invalid input! Please enter a valid integer.")

        except TypeError as e:
            print(e)
# Out:
# Enter a number:  89
# Prime number

# %%
class Prime:
    """
    Checks whether a number is prime or not.
    """

    def __init__(self, num):
        self.num = num

    def is_prime(self):
        if not isinstance(self.num, int):
            raise TypeError("Input must be an integer")

        if self.num <= 1:
            return False

        for i in range(2, self.num):
            if self.num % i == 0:
                return False

        return True


if __name__ == "__main__":
    try:
        user_input = int(input("Enter a number: "))
        prime_obj = Prime(user_input)
        result = prime_obj.is_prime()

        if result:
            print("Prime number")
        else:
            print("Not a prime number")

    except ValueError:
        print("Invalid input! Please enter a valid integer.")
    except TypeError as e:
        print(e)
# Out:
# Enter a number:  32
# Not a prime number
